# %% [markdown]
# ## [Students] Shopee Code League - Multi-Channel Contacts
# Customer Service element
# - Solution by Made Y
# - Understanding by Hendrik
#
# ### Background
# Customer service is an important element of the Shopee business, as providing a good service for our customers end-to-end is critical for business growth and brand image. Our goal is to resolve the customer’s issue within the least amount of time while requiring the least amount of customer effort.
#
# One measure for customer effort is the number of times a customer has to approach customer service over a particular issue, this is also known as the metric “Repeat Contact Rate” or RCR. Shopee is interested in studying the RCR in order to improve the effectiveness of our customer service.
#
# Customers can contact customer service via various channels such as the livechat function, filling up certain forms or calling in for help. Each time a customer contacts us with a new contact method, a new ticket is automatically generated. A complication arises when the same customer contacts us using different phone numbers or email addresses resulting in multiple tickets for the same issue. Hence, our challenge here is to identify how to merge relevant tickets together to create a complete picture of the customer issue and ultimately determine the RCR.
#
#
# ### Task
# - For each ticket, identify all contacts from each user if they have the same contact information.
# - For the purpose of this question, assume that all contacts from the same Phone Number / Email are the same user.
#
# ### Basic Concepts
# - Each Order ID represents a transaction in Shopee.
# - Each Id represents the Ticket Id made to Shopee Customer Service.
# - All Phone Numbers are stored without the country code and the country code can be ignored.
# - Contacts represent the number of times a user reached out to us in that particular ticket (Email, Call, Livechat etc.)
# - If a value is NA means that the system or agent has no record of that value.

# %% [markdown]
# https://articlearn.id/article/9b7ff55c-shopee-code-league-2021-multi-channel-con/

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_json('contacts.json')

# %%
df.head()
# Out:
#    Id               Email         Phone  Contacts                    OrderId
# 0   0      gkzAbIy@qq.com                       1
# 1   1                      329442681752         4  vDDJJcxfLtSfkooPhbYnJdxov
# 2   2                        9125983679         0
# 3   3  mdllpYmE@gmail.com                       0  bHquEnCbbsGLqllwryxPsNOxa
# 4   4                         300364407         2

# %%
npdata = df.values

# %%
npdata
# Out:
# array([[0, 'gkzAbIy@qq.com', '', 1, ''],
#        [1, '', '329442681752', 4, 'vDDJJcxfLtSfkooPhbYnJdxov'],
#        [2, '', '9125983679', 0, ''],
#        ...,
#        [499997, '', '4541459979', 2, 'beXCZSzcHaBwAYoDcpQqjuAFO'],
#        [499998, 'RzSDsyH@hotmail.com', '98947185431', 1,
#         'ehjeFACGiwrERQxbziMxwOWku'],
#        [499999, '', '880053388839', 0, 'JibSBRgzYdfzkzbTuGUXrcvDX']],
#       dtype=object)

# %% [markdown]
# df.values is gives us dataframe values as numpy array object and it removes index of the table(shows data only)

# %% [markdown]
# Approach
# - Create empty dictionaries to store all data needed for final submission

# %%
memory = {}
connections = {}

# %% [markdown]
# Make a function called add_memory for ticket_id and value with conditional statement, if a value isn't empty value then the value added into the ticket_id in the memory named value. else/if value equals to empty data then make a dictionary for ticket_id to store into value in the memory
#
# use loop function to get data from dataframe values as numpy object. The principle of getting the data is similar to the normal dataframe where data divided into column and row, since the npdata applies values as numpy array object, there's no index, so if we want to take based on column then apply 0,1,2,3,4,... as a header.

# %%
def add_memory(ticket_id, value):
    if value != "":
        if value in memory:
            memory[value].add(ticket_id)
            return
        memory[value] = {ticket_id}

for i in npdata:
    ticket_id = i[0]
    
    # Order Id
    add_memory(ticket_id, i[4])
    # Email
    add_memory(ticket_id, i[1])
    # Phone
    add_memory(ticket_id, i[2])

# %% [markdown]
# Make a simple loop to trace values with same contact information
# - Trace values for each ticket_id(ids)
# - If the value has connection, then apply union operation to new connection(ids) with old connections(ids)
# - set() method is used to convert any of the iterable to sequence of iterable elements with distinct elements
# - in the end, put all data in the connections dictionary which is made before

# %%
for ids in memory.values():
    current_connection = set(ids)

    for j in ids:
        if j in connections:
            current_connection.update(connections[j])

    for j in current_connection:
        connections[j] = current_connection

# %% [markdown]
# - All traces are recorded
# - Final step is to calculate the contacts for each ticket_id which has multiple contact informations

# %%
output = []
for ticket_id, trace in sorted(connections.items()):
    contacts = np.sum(npdata[list(trace), 3])
    trace = "-".join([str(_id) for _id in sorted(trace)])
    answer = "{}, {}".format(trace, contacts)
    output.append({"ticket_id": ticket_id,  "ticket_trace/contact": answer})

# %%
output
# Out:
# [{'ticket_id': 0, 'ticket_trace/contact': '0, 1'},
#  {'ticket_id': 1,
#   'ticket_trace/contact': '1-2458-98519-115061-140081-165605-476346, 12'},
#  {'ticket_id': 2, 'ticket_trace/contact': '2-159312-322639-348955, 4'},
#  {'ticket_id': 3, 'ticket_trace/contact': '3, 0'},
#  {'ticket_id': 4, 'ticket_trace/contact': '4, 2'},
#  {'ticket_id': 5,
#   'ticket_trace/contact': '5-50-212533-215197-226720-383605-404324-458692-482810, 15'},
#  {'ticket_id': 6, 'ticket_trace/contact': '6-38-32871-142067-236367, 13'},
#  {'ticket_id': 7, 'ticket_trace/contact': '7, 1'},
#  {'ticket_id': 8, 'ticket_trace/contact': '8-183160-406623, 5'},
#  {'ticket_id': 9,
#   'ticket_trace/contact': '9-13-16708-33415-343161-417916-468927-484896, 8'},
#  {'ticket_id': 10, 'ticket_trace/contact': '10-93270, 7'},
#  {'ticket_id': 11, 'ticket_trace/contact': '11-244207, 3'},
#  {'ticket_id': 12, 'ticket_trace/contact': '12-160893-480595, 7'},
#  {'ticket_id': 13,
#   'ticket_trace/contact': '9-13-16708-33415-343161-417916-468927-484896, 8'},
#  {'ticket_id': 14,
#   'ticket_trace/contact': '14-65749-83313-267520-323910-359095, 10'},
#  {'ticket_id': 15, 'ticket_trace/contact': '15-17-21197-486106, 14'},
#  {'ticket_id': 16, 'ticket_trace/contact': '16, 0'},
#  {'ticket_id': 17, 'ticket_trace/contact': '15-17-21197-486106, 14'},
#  {'ticket_id': 18,
#   'ticket_trace/contact': '18-10380-26580-70474-70621-79466-121268-159329-176080-235210-261681-274269-327057-382449-415657-450623, 28'},
#  {'ticket_id': 19, 'ticket_trace/contact': '19-406780, 1'},
#  {'ticket_id': 20, 'ticket_trace/contact': '20, 3'},
#  {'ticket_id': 21, 'ticket_trace/contact': '21-499255, 5'},
#  {'ticket_id': 22,
#   'ticket_trace/contact': '22-4562-106701-231013-269015-298102-408655-416176-453177-473446, 10'},
#  {'ticket_id': 23, 'ticket_trace/contact': '23-1944-49506-192016, 15'},
#  {'ticket_id': 24,
#   'ticket_trace/contact': '24-1485-112670-118722-139764-235060-278469-386186-412121, 19'},
#  {'ticket_id': 25, 'ticket_trace/contact': '25, 2'},
#  {'ticket_id': 26, 'ticket_trace/contact': '26-229592-402598, 2'},
#  {'ticket_id': 27,
#   'ticket_trace/contact': '27-246-41540-112494-158446-237701-259786, 14'},
#  {'ticket_id': 28,
#   'ticket_trace/contact': '28-1271-26068-177136-271446-382292-487899-495579, 14'},
#  {'ticket_id': 29,
#   'ticket_trace/contact': '29-64140-364569-437861-463960, 10'},
#  {'ticket_id': 30, 'ticket_trace/contact': '30-19563, 4'},
#  {'ticket_id': 31, 'ticket_trace/contact': '31-66232, 0'},
#  {'ticket_id': 32, 'ticket_trace/contact': '32, 3'},
#  {'ticket_id': 33,
#   'ticket_trace/contact': '33-459-46643-117352-269224-499013, 13'},
#  {'ticket_id': 34, 'ticket_trace/contact': '34, 0'},
#  {'ticket_id': 35, 'ticket_trace/contact': '35-51, 5'},
#  {'ticket_id': 36, 'ticket_trace/contact': '36, 1'},
#  {'ticket_id': 37, 'ticket_trace/contact': '37-1864, 5'},
#  {'ticket_id': 38, 'ticket_trace/contact': '6-38-32871-142067-236367, 13'},
#  {'ticket_id': 39,
#   'ticket_trace/contact': '39-20375-23729-32596-39187-47554-95806-110030-122105-191174-254425-262931-285406-346215-354020-364596-461467-475371, 34'},
#  {'ticket_id': 40,
#   'ticket_trace/contact': '40-1182-28643-170845-171331-185008-196535-198449-208205-217500-239282-256779-264186-283948-296482-311837-313529-339743-373119-389380-395664-396104-419260-431243-454084-484815-491223-499570, 58'},
#  {'ticket_id': 41,
#   'ticket_trace/contact': '41-11667-64947-168137-275580-337549-366951, 9'},
#  {'ticket_id': 42, 'ticket_trace/contact': '42-164913, 6'},
#  {'ticket_id': 43, 'ticket_trace/contact': '43-286788-480546, 7'},
#  {'ticket_id': 44, 'ticket_trace/contact': '44-171746, 2'},
#  {'ticket_id': 45, 'ticket_trace/contact': '45, 3'},
#  {'ticket_id': 46, 'ticket_trace/contact': '46, 1'},
#  {'ticket_id': 47, 'ticket_trace/contact': '47, 1'},
#  {'ticket_id': 48, 'ticket_trace/contact': '48, 4'},
#  {'ticket_id': 49, 'ticket_trace/contact': '49-50840-179281, 5'},
#  {'ticket_id': 50,
#   'ticket_trace/contact': '5-50-212533-215197-226720-383605-404324-458692-482810, 15'},
#  {'ticket_id': 51, 'ticket_trace/contact': '35-51, 5'},
#  {'ticket_id': 52,
#   'ticket_trace/contact': '52-46079-114882-157219-340482-394326, 12'},
#  {'ticket_id': 53, 'ticket_trace/contact': '53, 0'},
#  {'ticket_id': 54, 'ticket_trace/contact': '54-378247, 6'},
#  {'ticket_id': 55, 'ticket_trace/contact': '55, 3'},
#  {'ticket_id': 56, 'ticket_trace/contact': '56, 3'},
#  {'ticket_id': 57,
#   'ticket_trace/contact': '57-1534-34572-40050-66405-111925-131269-174248-264710-298303-386483-393869-418805-460716-472554, 37'},
#  {'ticket_id': 58, 'ticket_trace/contact': '58, 3'},
#  {'ticket_id': 59, 'ticket_trace/contact': '59, 0'},
#  {'ticket_id': 60,
#   'ticket_trace/contact': '60-7964-13981-331792-426590-486286, 9'},
#  {'ticket_id': 61, 'ticket_trace/contact': '61, 1'},
#  {'ticket_id': 62,
#   'ticket_trace/contact': '62-9506-25476-92496-230246-298529-375889-379246-481395, 14'},
#  {'ticket_id': 63, 'ticket_trace/contact': '63-241115-471199, 4'},
#  {'ticket_id': 64, 'ticket_trace/contact': '64, 2'},
#  {'ticket_id': 65,
#   'ticket_trace/contact': '65-114641-169915-206935-357273, 15'},
#  {'ticket_id': 66, 'ticket_trace/contact': '66, 1'},
#  {'ticket_id': 67,
#   'ticket_trace/contact': '67-1576-111438-145889-190601-284496-439322-461215, 14'},
#  {'ticket_id': 68, 'ticket_trace/contact': '68-1321-187301-321667, 5'},
#  {'ticket_id': 69, 'ticket_trace/contact': '69-214159, 6'},
#  {'ticket_id': 70, 'ticket_trace/contact': '70, 3'},
#  {'ticket_id': 71,
#   'ticket_trace/contact': '71-335-2441-3783-10088-23134-48539-63028-87600-110495-125054-145501-152973-169975-171236-181647-213907-232849-238913-251219-263203-266190-301846-382923-397815-459512-478605, 61'},
#  {'ticket_id': 72, 'ticket_trace/contact': '72-414959, 1'},
#  {'ticket_id': 73, 'ticket_trace/contact': '73, 1'},
#  {'ticket_id': 74,
#   'ticket_trace/contact': '74-74819-146498-280238-332989-434328-491356, 12'},
#  {'ticket_id': 75, 'ticket_trace/contact': '75-366910, 7'},
#  {'ticket_id': 76, 'ticket_trace/contact': '76-470100, 0'},
#  {'ticket_id': 77, 'ticket_trace/contact': '77, 2'},
#  {'ticket_id': 78,
#   'ticket_trace/contact': '78-199488-266731-285621-468556, 15'},
#  {'ticket_id': 79, 'ticket_trace/contact': '79-151123, 4'},
#  {'ticket_id': 80,
#   'ticket_trace/contact': '80-38705-39843-122330-136069-138219-138888-140452-159022-195334-265667-296648-301815-370204-372153-389680-410682-416731, 31'},
#  {'ticket_id': 81, 'ticket_trace/contact': '81-151818-383073, 8'},
#  {'ticket_id': 82, 'ticket_trace/contact': '82-279875, 6'},
#  {'ticket_id': 83,
#   'ticket_trace/contact': '83-22387-24340-39776-47463-54994-126500-153101-175025-192415-202951-204437-235552-266341-292695-302668-354979-393915, 30'},
#  {'ticket_id': 84, 'ticket_trace/contact': '84, 0'},
#  {'ticket_id': 85, 'ticket_trace/contact': '85-271911, 5'},
#  {'ticket_id': 86, 'ticket_trace/contact': '86-247375-354315-447444, 12'},
#  {'ticket_id': 87, 'ticket_trace/contact': '87, 2'},
#  {'ticket_id': 88, 'ticket_trace/contact': '88, 0'},
#  {'ticket_id': 89, 'ticket_trace/contact': '89-316049-470531, 2'},
#  {'ticket_id': 90, 'ticket_trace/contact': '90-53830-272530-462213, 10'},
#  {'ticket_id': 91,
#   'ticket_trace/contact': '91-11428-46544-60777-62822-77764-82757-97152-101634-154339-155324-160152-163969-177073-189307-201173-207738-212878-219245-224737-228267-238605-305637-331943-332912-353023-356675-361432-377255-378577-391918-413237-446819, 53'},
#  {'ticket_id': 92, 'ticket_trace/contact': '92-51599-81863-287578, 7'},
#  {'ticket_id': 93, 'ticket_trace/contact': '93-463050, 3'},
#  {'ticket_id': 94,
#   'ticket_trace/contact': '94-198708-223721-225405-264494-269455-279700-423724-478525-497318, 21'},
#  {'ticket_id': 95, 'ticket_trace/contact': '95, 0'},
#  {'ticket_id': 96,
#   'ticket_trace/contact': '96-9854-58319-66706-116460-356800, 11'},
#  {'ticket_id': 97, 'ticket_trace/contact': '97, 3'},
#  {'ticket_id': 98, 'ticket_trace/contact': '98, 0'},
#  {'ticket_id': 99, 'ticket_trace/contact': '99-62730-115978-127705, 10'},
#  {'ticket_id': 100,
#   'ticket_trace/contact': '100-822-1157-79530-95287-109959-129043-146402-181117-205684-220328-280716-282502-306045-379958-437044-451994-475973, 38'},
#  {'ticket_id': 101,
#   'ticket_trace/contact': '101-54178-56651-360820-415852, 14'},
#  {'ticket_id': 102, 'ticket_trace/contact': '102-466297, 5'},
#  {'ticket_id': 103,
#   'ticket_trace/contact': '103-2788-26590-298414-336851-337168-429453, 17'},
#  {'ticket_id': 104, 'ticket_trace/contact': '104, 2'},
#  {'ticket_id': 105,
#   'ticket_trace/contact': '105-5597-15905-68965-89832-290943-360283-484596-486426, 16'},
#  {'ticket_id': 106,
#   'ticket_trace/contact': '106-856-164892-298789-478387-494415, 6'},
#  {'ticket_id': 107,
#   'ticket_trace/contact': '107-465-178290-280212-316970, 12'},
#  {'ticket_id': 108,
#   'ticket_trace/contact': '108-68001-87503-97890-109593-181236-470335, 16'},
#  {'ticket_id': 109, 'ticket_trace/contact': '109-294-237280, 11'},
#  {'ticket_id': 110,
#   'ticket_trace/contact': '110-60486-63603-157993-429244-460054, 3'},
#  {'ticket_id': 111, 'ticket_trace/contact': '111, 4'},
#  {'ticket_id': 112,
#   'ticket_trace/contact': '112-135-65778-182934-188141-240831-289600-397798-429441-456371-463263-467248, 27'},
#  {'ticket_id': 113, 'ticket_trace/contact': '113-409673-413629, 4'},
#  {'ticket_id': 114, 'ticket_trace/contact': '114, 4'},
#  {'ticket_id': 115, 'ticket_trace/contact': '115-215373-303417, 7'},
#  {'ticket_id': 116,
#   'ticket_trace/contact': '116-17086-19803-30727-48616-75473-95005-221885-275026-292480-301164-302539-365527-366421-379989-384752-388164-415826-471003-478195-494089-498208, 39'},
#  {'ticket_id': 117, 'ticket_trace/contact': '117-184856-355948, 5'},
#  {'ticket_id': 118, 'ticket_trace/contact': '118-18056-323184, 5'},
#  {'ticket_id': 119,
#   'ticket_trace/contact': '119-83681-177581-301632-437059, 10'},
#  {'ticket_id': 120, 'ticket_trace/contact': '120, 2'},
#  {'ticket_id': 121,
#   'ticket_trace/contact': '121-12840-23604-68014-116467-465574, 7'},
#  {'ticket_id': 122, 'ticket_trace/contact': '122, 1'},
#  {'ticket_id': 123,
#   'ticket_trace/contact': '123-93061-334454-349627-462949-491626, 7'},
#  {'ticket_id': 124, 'ticket_trace/contact': '124-96409-216113, 4'},
#  {'ticket_id': 125, 'ticket_trace/contact': '125, 1'},
#  {'ticket_id': 126, 'ticket_trace/contact': '126, 1'},
#  {'ticket_id': 127, 'ticket_trace/contact': '127-76310-449222, 7'},
#  {'ticket_id': 128, 'ticket_trace/contact': '128-429492, 5'},
#  {'ticket_id': 129, 'ticket_trace/contact': '129-106690-121941, 6'},
#  {'ticket_id': 130, 'ticket_trace/contact': '130, 3'},
#  {'ticket_id': 131,
#   'ticket_trace/contact': '131-39449-222540-366341-400892-481588-492598, 11'},
#  {'ticket_id': 132,
#   'ticket_trace/contact': '132-14271-34614-127193-137580-156051-162374-166962-170043-181603-187111-217593-257791-278357-289324-349079-367644-369744-453735-468043, 42'},
#  {'ticket_id': 133, 'ticket_trace/contact': '133-97036-445333, 1'},
#  {'ticket_id': 134, 'ticket_trace/contact': '134, 0'},
#  {'ticket_id': 135,
#   'ticket_trace/contact': '112-135-65778-182934-188141-240831-289600-397798-429441-456371-463263-467248, 27'},
#  {'ticket_id': 136, 'ticket_trace/contact': '136-69515-108365-473933, 8'},
#  {'ticket_id': 137, 'ticket_trace/contact': '137-107753, 6'},
#  {'ticket_id': 138,
#   'ticket_trace/contact': '138-106827-188357-216438-241143-281849-389414-428562, 15'},
#  {'ticket_id': 139, 'ticket_trace/contact': '139, 1'},
#  {'ticket_id': 140, 'ticket_trace/contact': '140-304532, 3'},
#  {'ticket_id': 141, 'ticket_trace/contact': '141-99896, 5'},
#  {'ticket_id': 142, 'ticket_trace/contact': '142, 1'},
#  {'ticket_id': 143, 'ticket_trace/contact': '143, 4'},
#  {'ticket_id': 144, 'ticket_trace/contact': '144, 0'},
#  {'ticket_id': 145,
#   'ticket_trace/contact': '145-89646-217781-234084-290087-365222-410226-425856, 14'},
#  {'ticket_id': 146, 'ticket_trace/contact': '146-298152, 5'},
#  {'ticket_id': 147, 'ticket_trace/contact': '147, 2'},
#  {'ticket_id': 148,
#   'ticket_trace/contact': '148-33408-81493-271214-286693-303270, 13'},
#  {'ticket_id': 149, 'ticket_trace/contact': '149-30279, 5'},
#  {'ticket_id': 150, 'ticket_trace/contact': '150, 1'},
#  {'ticket_id': 151, 'ticket_trace/contact': '151, 2'},
#  {'ticket_id': 152, 'ticket_trace/contact': '152-359279, 5'},
#  {'ticket_id': 153, 'ticket_trace/contact': '153-76417, 6'},
#  {'ticket_id': 154, 'ticket_trace/contact': '154-105122, 3'},
#  {'ticket_id': 155, 'ticket_trace/contact': '155-81016-485385, 8'},
#  {'ticket_id': 156, 'ticket_trace/contact': '156, 2'},
#  {'ticket_id': 157, 'ticket_trace/contact': '157, 3'},
#  {'ticket_id': 158, 'ticket_trace/contact': '158-313250, 5'},
#  {'ticket_id': 159, 'ticket_trace/contact': '159, 2'},
#  {'ticket_id': 160, 'ticket_trace/contact': '160-88820-173595-213755, 10'},
#  {'ticket_id': 161,
#   'ticket_trace/contact': '161-10153-44305-72835-88731-171974-293201-349911-380974-483377, 20'},
#  {'ticket_id': 162, 'ticket_trace/contact': '162, 1'},
#  {'ticket_id': 163, 'ticket_trace/contact': '163-79377-280419-405439, 7'},
#  {'ticket_id': 164,
#   'ticket_trace/contact': '164-937-1259-1610-12101-14883-56600-57027-76148-110666-145523-160154-282091-411076-477605, 32'},
#  {'ticket_id': 165, 'ticket_trace/contact': '165, 3'},
#  {'ticket_id': 166, 'ticket_trace/contact': '166, 4'},
#  {'ticket_id': 167, 'ticket_trace/contact': '167, 2'},
#  {'ticket_id': 168, 'ticket_trace/contact': '168-386-209740-392461, 12'},
#  {'ticket_id': 169, 'ticket_trace/contact': '169, 0'},
#  {'ticket_id': 170, 'ticket_trace/contact': '170, 1'},
#  {'ticket_id': 171,
#   'ticket_trace/contact': '171-29356-42724-70858-90425-163627-474980-479996, 14'},
#  {'ticket_id': 172, 'ticket_trace/contact': '172, 3'},
#  {'ticket_id': 173, 'ticket_trace/contact': '173-133089, 6'},
#  {'ticket_id': 174, 'ticket_trace/contact': '174-4484-459442, 5'},
#  {'ticket_id': 175, 'ticket_trace/contact': '175, 3'},
#  {'ticket_id': 176, 'ticket_trace/contact': '176-304820-311652, 7'},
#  {'ticket_id': 177, 'ticket_trace/contact': '177-483854, 5'},
#  {'ticket_id': 178,
#   'ticket_trace/contact': '178-1299-1918-9437-14178-40898-73139-74088-90912-110829-121708-123015-166455-169144-183274-190954-198810-203228-224509-242675-268841-300059-323713-338541-342439-342853-363579-384322-397156-398477-399635-428730-473009-480875, 69'},
#  {'ticket_id': 179, 'ticket_trace/contact': '179, 1'},
#  {'ticket_id': 180, 'ticket_trace/contact': '180-14872-268358-415071, 11'},
#  {'ticket_id': 181, 'ticket_trace/contact': '181, 4'},
#  {'ticket_id': 182,
#   'ticket_trace/contact': '182-6268-107985-223401-313867-465204, 14'},
#  {'ticket_id': 183,
#   'ticket_trace/contact': '183-30462-41173-86814-176299-221556-351621-406688-407066-476029-483939, 22'},
#  {'ticket_id': 184, 'ticket_trace/contact': '184-405992, 5'},
#  {'ticket_id': 185,
#   'ticket_trace/contact': '185-13333-118012-203759-288495-356636-360010-496266, 17'},
#  {'ticket_id': 186, 'ticket_trace/contact': '186, 4'},
#  {'ticket_id': 187, 'ticket_trace/contact': '187-111412, 4'},
#  {'ticket_id': 188, 'ticket_trace/contact': '188, 2'},
#  {'ticket_id': 189, 'ticket_trace/contact': '189, 3'},
#  {'ticket_id': 190,
#   'ticket_trace/contact': '190-16313-119170-201448-295936-437023-437671, 8'},
#  {'ticket_id': 191, 'ticket_trace/contact': '191, 0'},
#  {'ticket_id': 192,
#   'ticket_trace/contact': '192-173505-174551-257865-291979, 12'},
#  {'ticket_id': 193, 'ticket_trace/contact': '193-79361, 8'},
#  {'ticket_id': 194, 'ticket_trace/contact': '194-4132-205205, 4'},
#  {'ticket_id': 195, 'ticket_trace/contact': '195, 0'},
#  {'ticket_id': 196,
#   'ticket_trace/contact': '196-101723-115356-150332-269570-290992-291687-359225, 13'},
#  {'ticket_id': 197, 'ticket_trace/contact': '197, 3'},
#  {'ticket_id': 198, 'ticket_trace/contact': '198-194903-360906, 3'},
#  {'ticket_id': 199, 'ticket_trace/contact': '199, 2'},
#  {'ticket_id': 200, 'ticket_trace/contact': '200, 1'},
#  {'ticket_id': 201,
#   'ticket_trace/contact': '201-4060-17801-22963-29354-32129-58057-66410-87399-94480-104000-284402-291787-307533-337149-373534-403554-409992, 32'},
#  {'ticket_id': 202, 'ticket_trace/contact': '202, 1'},
#  {'ticket_id': 203, 'ticket_trace/contact': '203, 0'},
#  {'ticket_id': 204,
#   'ticket_trace/contact': '204-3869-11043-22817-61387-212977-254444-254647-260819-320826-324003-336670-374217, 23'},
#  {'ticket_id': 205,
#   'ticket_trace/contact': '205-559-850-51845-215655-252724-354483-372904-465114, 24'},
#  {'ticket_id': 206, 'ticket_trace/contact': '206, 3'},
#  {'ticket_id': 207, 'ticket_trace/contact': '207-307378, 4'},
#  {'ticket_id': 208, 'ticket_trace/contact': '208-303253-316869, 1'},
#  {'ticket_id': 209,
#   'ticket_trace/contact': '209-7891-98235-128312-444182-459237, 10'},
#  {'ticket_id': 210, 'ticket_trace/contact': '210-402055, 5'},
#  {'ticket_id': 211, 'ticket_trace/contact': '211, 2'},
#  {'ticket_id': 212, 'ticket_trace/contact': '212, 0'},
#  {'ticket_id': 213, 'ticket_trace/contact': '213-96857-480259, 7'},
#  {'ticket_id': 214, 'ticket_trace/contact': '214, 4'},
#  {'ticket_id': 215, 'ticket_trace/contact': '215, 3'},
#  {'ticket_id': 216, 'ticket_trace/contact': '216, 4'},
#  {'ticket_id': 217, 'ticket_trace/contact': '217-326355-487124-489730, 9'},
#  {'ticket_id': 218, 'ticket_trace/contact': '218, 1'},
#  {'ticket_id': 219, 'ticket_trace/contact': '219-380008, 0'},
#  {'ticket_id': 220, 'ticket_trace/contact': '220, 2'},
#  {'ticket_id': 221, 'ticket_trace/contact': '221-64580-163948-334244, 7'},
#  {'ticket_id': 222,
#   'ticket_trace/contact': '222-2787-9181-17960-33581-147881-272867-296001-420735-422982-445542-458888-464908, 27'},
#  {'ticket_id': 223, 'ticket_trace/contact': '223-91460-301712, 6'},
#  {'ticket_id': 224, 'ticket_trace/contact': '224-817-51435-316595, 8'},
#  {'ticket_id': 225, 'ticket_trace/contact': '225-252674-393542, 5'},
#  {'ticket_id': 226, 'ticket_trace/contact': '226, 4'},
#  {'ticket_id': 227,
#   'ticket_trace/contact': '227-46904-57523-104845-344710, 10'},
#  {'ticket_id': 228, 'ticket_trace/contact': '228-236443-490834, 3'},
#  {'ticket_id': 229, 'ticket_trace/contact': '229-260663, 1'},
#  {'ticket_id': 230, 'ticket_trace/contact': '230-190456-272016, 4'},
#  {'ticket_id': 231,
#   'ticket_trace/contact': '231-58285-222589-230055-254384, 16'},
#  {'ticket_id': 232,
#   'ticket_trace/contact': '232-203968-327056-347654-469710, 12'},
#  {'ticket_id': 233, 'ticket_trace/contact': '233-484879, 3'},
#  {'ticket_id': 234,
#   'ticket_trace/contact': '234-34171-165732-233819-454479, 14'},
#  {'ticket_id': 235,
#   'ticket_trace/contact': '235-85009-141554-198545-314321-346872-363038-413468, 6'},
#  {'ticket_id': 236,
#   'ticket_trace/contact': '236-23828-87237-87239-169662-351448, 8'},
#  {'ticket_id': 237,
#   'ticket_trace/contact': '237-22245-78477-249023-368510-409086-440015-474266, 9'},
#  {'ticket_id': 238, 'ticket_trace/contact': '238-236143, 4'},
#  {'ticket_id': 239, 'ticket_trace/contact': '239, 3'},
#  {'ticket_id': 240,
#   'ticket_trace/contact': '240-157468-347261-378121-462828, 7'},
#  {'ticket_id': 241, 'ticket_trace/contact': '241-168214, 2'},
#  {'ticket_id': 242, 'ticket_trace/contact': '242-33469, 4'},
#  {'ticket_id': 243, 'ticket_trace/contact': '243-386227-390625, 6'},
#  {'ticket_id': 244, 'ticket_trace/contact': '244-155428-218572-458207, 10'},
#  {'ticket_id': 245, 'ticket_trace/contact': '245-170587, 8'},
#  {'ticket_id': 246,
#   'ticket_trace/contact': '27-246-41540-112494-158446-237701-259786, 14'},
#  {'ticket_id': 247,
#   'ticket_trace/contact': '247-184678-261881-302311-328828-471943, 11'},
#  {'ticket_id': 248, 'ticket_trace/contact': '248-42707-97987-343852, 6'},
#  {'ticket_id': 249,
#   'ticket_trace/contact': '249-801-30407-329017-337064-442715, 10'},
#  {'ticket_id': 250,
#   'ticket_trace/contact': '250-75916-76487-81701-328642-417767, 14'},
#  {'ticket_id': 251, 'ticket_trace/contact': '251, 0'},
#  {'ticket_id': 252,
#   'ticket_trace/contact': '252-67049-118239-292410-308573-335694, 13'},
#  {'ticket_id': 253, 'ticket_trace/contact': '253-318964-416594, 4'},
#  {'ticket_id': 254, 'ticket_trace/contact': '254, 3'},
#  {'ticket_id': 255,
#   'ticket_trace/contact': '255-288-3008-58526-65707-123556-125574-273552-338481-428798-462239, 25'},
#  {'ticket_id': 256,
#   'ticket_trace/contact': '256-25739-49881-212604-344882-458681, 11'},
#  {'ticket_id': 257, 'ticket_trace/contact': '257, 4'},
#  {'ticket_id': 258,
#   'ticket_trace/contact': '258-27758-203138-338962-471352, 11'},
#  {'ticket_id': 259, 'ticket_trace/contact': '259-276554-461696, 5'},
#  {'ticket_id': 260,
#   'ticket_trace/contact': '260-67280-103180-217219-295684-316414-490607, 13'},
#  {'ticket_id': 261, 'ticket_trace/contact': '261-357027-443063, 6'},
#  {'ticket_id': 262, 'ticket_trace/contact': '262-218895, 0'},
#  {'ticket_id': 263,
#   'ticket_trace/contact': '263-55696-87172-91553-158352-366661-475711, 13'},
#  {'ticket_id': 264, 'ticket_trace/contact': '264-212081-380046, 5'},
#  {'ticket_id': 265, 'ticket_trace/contact': '265-191908-279153-405957, 9'},
#  {'ticket_id': 266, 'ticket_trace/contact': '266-200823-267604-321344, 7'},
#  {'ticket_id': 267,
#   'ticket_trace/contact': '267-9538-235176-259952-272626-319700-485289, 21'},
#  {'ticket_id': 268, 'ticket_trace/contact': '268, 4'},
#  {'ticket_id': 269, 'ticket_trace/contact': '269, 4'},
#  {'ticket_id': 270, 'ticket_trace/contact': '270-190603, 5'},
#  {'ticket_id': 271, 'ticket_trace/contact': '271-44474-83654-349833, 3'},
#  {'ticket_id': 272, 'ticket_trace/contact': '272, 1'},
#  {'ticket_id': 273, 'ticket_trace/contact': '273, 4'},
#  {'ticket_id': 274, 'ticket_trace/contact': '274-190245, 3'},
#  {'ticket_id': 275, 'ticket_trace/contact': '275-326298, 5'},
#  {'ticket_id': 276, 'ticket_trace/contact': '276-408958-451746, 8'},
#  {'ticket_id': 277, 'ticket_trace/contact': '277, 4'},
#  {'ticket_id': 278, 'ticket_trace/contact': '278-267037, 4'},
#  {'ticket_id': 279, 'ticket_trace/contact': '279, 0'},
#  {'ticket_id': 280,
#   'ticket_trace/contact': '280-5821-92383-97338-139139-422180-491944, 11'},
#  {'ticket_id': 281, 'ticket_trace/contact': '281-97617, 3'},
#  {'ticket_id': 282, 'ticket_trace/contact': '282-2369-31935-63210, 5'},
#  {'ticket_id': 283, 'ticket_trace/contact': '283, 3'},
#  {'ticket_id': 284, 'ticket_trace/contact': '284-461926, 5'},
#  {'ticket_id': 285, 'ticket_trace/contact': '285, 3'},
#  {'ticket_id': 286, 'ticket_trace/contact': '286, 1'},
#  {'ticket_id': 287, 'ticket_trace/contact': '287, 1'},
#  {'ticket_id': 288,
#   'ticket_trace/contact': '255-288-3008-58526-65707-123556-125574-273552-338481-428798-462239, 25'},
#  {'ticket_id': 289, 'ticket_trace/contact': '289-434889, 6'},
#  {'ticket_id': 290, 'ticket_trace/contact': '290-467081, 1'},
#  {'ticket_id': 291, 'ticket_trace/contact': '291-1127, 3'},
#  {'ticket_id': 292, 'ticket_trace/contact': '292, 2'},
#  {'ticket_id': 293, 'ticket_trace/contact': '293, 2'},
#  {'ticket_id': 294, 'ticket_trace/contact': '109-294-237280, 11'},
#  {'ticket_id': 295, 'ticket_trace/contact': '295-423761, 3'},
#  {'ticket_id': 296, 'ticket_trace/contact': '296, 4'},
#  {'ticket_id': 297,
#   'ticket_trace/contact': '297-2878-77480-102266-116938-127104-139408-326989-483374, 17'},
#  {'ticket_id': 298, 'ticket_trace/contact': '298, 3'},
#  {'ticket_id': 299,
#   'ticket_trace/contact': '299-24503-62954-79753-160035-318065-330989, 13'},
#  {'ticket_id': 300, 'ticket_trace/contact': '300, 4'},
#  {'ticket_id': 301, 'ticket_trace/contact': '301, 2'},
#  {'ticket_id': 302, 'ticket_trace/contact': '302, 4'},
#  {'ticket_id': 303,
#   'ticket_trace/contact': '303-108436-108655-171494-256206, 12'},
#  {'ticket_id': 304, 'ticket_trace/contact': '304, 2'},
#  {'ticket_id': 305, 'ticket_trace/contact': '305-48930, 1'},
#  {'ticket_id': 306, 'ticket_trace/contact': '306-2224, 7'},
#  {'ticket_id': 307,
#   'ticket_trace/contact': '307-2483-34074-84840-131110-313569, 10'},
#  {'ticket_id': 308,
#   'ticket_trace/contact': '308-13146-73086-146543-410105-448492, 8'},
#  {'ticket_id': 309, 'ticket_trace/contact': '309, 3'},
#  {'ticket_id': 310, 'ticket_trace/contact': '310, 3'},
#  {'ticket_id': 311, 'ticket_trace/contact': '311, 1'},
#  {'ticket_id': 312,
#   'ticket_trace/contact': '312-45749-196459-274103-339839-431159-487638, 11'},
#  {'ticket_id': 313,
#   'ticket_trace/contact': '313-107387-110997-154388-449288, 10'},
#  {'ticket_id': 314, 'ticket_trace/contact': '314, 3'},
#  {'ticket_id': 315, 'ticket_trace/contact': '315-22526, 3'},
#  {'ticket_id': 316,
#   'ticket_trace/contact': '316-54997-144240-233813-273540-317161, 7'},
#  {'ticket_id': 317, 'ticket_trace/contact': '317-311774, 2'},
#  {'ticket_id': 318, 'ticket_trace/contact': '318-5762, 2'},
#  {'ticket_id': 319, 'ticket_trace/contact': '319, 1'},
#  {'ticket_id': 320,
#   'ticket_trace/contact': '320-1480-7918-44840-52395-73227-142452-168748-206459-254348-367533-455199, 21'},
#  {'ticket_id': 321, 'ticket_trace/contact': '321, 1'},
#  {'ticket_id': 322,
#   'ticket_trace/contact': '322-32512-119851-189118-265917-280156-405305-408187, 26'},
#  {'ticket_id': 323, 'ticket_trace/contact': '323, 1'},
#  {'ticket_id': 324,
#   'ticket_trace/contact': '324-39182-39366-299746-322274-406160-433055, 15'},
#  {'ticket_id': 325, 'ticket_trace/contact': '325-48332-122497-265293, 9'},
#  {'ticket_id': 326, 'ticket_trace/contact': '326-495698, 5'},
#  {'ticket_id': 327,
#   'ticket_trace/contact': '327-1305-17714-40292-65589-141809-292534-293371-323771-337542-440489-472944-474489, 20'},
#  {'ticket_id': 328, 'ticket_trace/contact': '328, 0'},
#  {'ticket_id': 329, 'ticket_trace/contact': '329, 3'},
#  {'ticket_id': 330, 'ticket_trace/contact': '330, 2'},
#  {'ticket_id': 331, 'ticket_trace/contact': '331, 0'},
#  {'ticket_id': 332, 'ticket_trace/contact': '332, 0'},
#  {'ticket_id': 333, 'ticket_trace/contact': '333-182251-441951, 7'},
#  {'ticket_id': 334,
#   'ticket_trace/contact': '334-82081-165951-169482-252260-292013-337611-384231-474329, 11'},
#  {'ticket_id': 335,
#   'ticket_trace/contact': '71-335-2441-3783-10088-23134-48539-63028-87600-110495-125054-145501-152973-169975-171236-181647-213907-232849-238913-251219-263203-266190-301846-382923-397815-459512-478605, 61'},
#  {'ticket_id': 336, 'ticket_trace/contact': '336, 0'},
#  {'ticket_id': 337, 'ticket_trace/contact': '337, 3'},
#  {'ticket_id': 338, 'ticket_trace/contact': '338-56044-81500-380656, 6'},
#  {'ticket_id': 339,
#   'ticket_trace/contact': '339-62929-119263-129288-144989-163746-187586-234861-242331-280975-283146-316339-331363-355586-382752-396916-431625-439974-467010-489097, 39'},
#  {'ticket_id': 340,
#   'ticket_trace/contact': '340-29567-53344-60135-118442-244959-253262-350383-497541, 17'},
#  {'ticket_id': 341, 'ticket_trace/contact': '341-264598, 1'},
#  {'ticket_id': 342, 'ticket_trace/contact': '342, 2'},
#  {'ticket_id': 343, 'ticket_trace/contact': '343-111404-270553, 11'},
#  {'ticket_id': 344, 'ticket_trace/contact': '344, 3'},
#  {'ticket_id': 345,
#   'ticket_trace/contact': '345-95369-165023-179212-218233-262059-319785-335800-378816-463930-473232, 19'},
#  {'ticket_id': 346,
#   'ticket_trace/contact': '346-35262-158341-181020-182431-203102-215940-239664-260453-266863-293118-410564-429059-434630-439120, 32'},
#  {'ticket_id': 347, 'ticket_trace/contact': '347-1514, 1'},
#  {'ticket_id': 348, 'ticket_trace/contact': '348-93886-97077-312411, 7'},
#  {'ticket_id': 349, 'ticket_trace/contact': '349, 1'},
#  {'ticket_id': 350, 'ticket_trace/contact': '350, 0'},
#  {'ticket_id': 351, 'ticket_trace/contact': '351-59225, 1'},
#  {'ticket_id': 352, 'ticket_trace/contact': '352-335262, 0'},
#  {'ticket_id': 353, 'ticket_trace/contact': '353-41012, 5'},
#  {'ticket_id': 354, 'ticket_trace/contact': '354-249524, 5'},
#  {'ticket_id': 355, 'ticket_trace/contact': '355, 0'},
#  {'ticket_id': 356, 'ticket_trace/contact': '356-203920, 4'},
#  {'ticket_id': 357, 'ticket_trace/contact': '357-313121, 4'},
#  {'ticket_id': 358, 'ticket_trace/contact': '358-103076-437867-469004, 7'},
#  {'ticket_id': 359, 'ticket_trace/contact': '359-140407-375821, 5'},
#  {'ticket_id': 360, 'ticket_trace/contact': '360-254944, 1'},
#  {'ticket_id': 361, 'ticket_trace/contact': '361-172826, 6'},
#  {'ticket_id': 362, 'ticket_trace/contact': '362, 3'},
#  {'ticket_id': 363,
#   'ticket_trace/contact': '363-17643-46868-87603-87616-291558, 7'},
#  {'ticket_id': 364, 'ticket_trace/contact': '364, 4'},
#  {'ticket_id': 365, 'ticket_trace/contact': '365-409228, 3'},
#  {'ticket_id': 366, 'ticket_trace/contact': '366, 3'},
#  {'ticket_id': 367, 'ticket_trace/contact': '367, 3'},
#  {'ticket_id': 368, 'ticket_trace/contact': '368-109945-213909-411281, 3'},
#  {'ticket_id': 369, 'ticket_trace/contact': '369-169696-193546, 7'},
#  {'ticket_id': 370,
#   'ticket_trace/contact': '370-9947-10507-17212-58652-60959-159861-175804-180515-335008-358155-360968-366199-414961-494608, 27'},
#  {'ticket_id': 371, 'ticket_trace/contact': '371, 1'},
#  {'ticket_id': 372,
#   'ticket_trace/contact': '372-49667-98893-231382-241899-248868-291966-461810, 17'},
#  {'ticket_id': 373, 'ticket_trace/contact': '373, 2'},
#  {'ticket_id': 374, 'ticket_trace/contact': '374-160906-228844, 7'},
#  {'ticket_id': 375, 'ticket_trace/contact': '375-238067, 1'},
#  {'ticket_id': 376, 'ticket_trace/contact': '376-416-77441-180802-380155, 9'},
#  {'ticket_id': 377, 'ticket_trace/contact': '377, 1'},
#  {'ticket_id': 378,
#   'ticket_trace/contact': '378-26718-66787-114967-194117-493306, 8'},
#  {'ticket_id': 379,
#   'ticket_trace/contact': '379-35435-72646-307540-371598, 11'},
#  {'ticket_id': 380,
#   'ticket_trace/contact': '380-12057-33029-41545-251427-296297-407847-481539, 14'},
#  {'ticket_id': 381, 'ticket_trace/contact': '381, 4'},
#  {'ticket_id': 382, 'ticket_trace/contact': '382-230455-276269, 2'},
#  {'ticket_id': 383,
#   'ticket_trace/contact': '383-349010-353347-402540-489116, 9'},
#  {'ticket_id': 384, 'ticket_trace/contact': '384-166008-187039-354294, 8'},
#  {'ticket_id': 385, 'ticket_trace/contact': '385, 1'},
#  {'ticket_id': 386, 'ticket_trace/contact': '168-386-209740-392461, 12'},
#  {'ticket_id': 387, 'ticket_trace/contact': '387-468001, 7'},
#  {'ticket_id': 388, 'ticket_trace/contact': '388, 2'},
#  {'ticket_id': 389, 'ticket_trace/contact': '389, 2'},
#  {'ticket_id': 390, 'ticket_trace/contact': '390, 0'},
#  {'ticket_id': 391, 'ticket_trace/contact': '391-41808-97714-230594, 4'},
#  {'ticket_id': 392, 'ticket_trace/contact': '392, 1'},
#  {'ticket_id': 393, 'ticket_trace/contact': '393, 1'},
#  {'ticket_id': 394, 'ticket_trace/contact': '394, 1'},
#  {'ticket_id': 395,
#   'ticket_trace/contact': '395-39473-40930-58392-84190-124259-143082-288969-296779-300121, 14'},
#  {'ticket_id': 396,
#   'ticket_trace/contact': '396-141529-154204-245805-441342-475761, 14'},
#  {'ticket_id': 397, 'ticket_trace/contact': '397, 3'},
#  {'ticket_id': 398, 'ticket_trace/contact': '398-23104, 0'},
#  {'ticket_id': 399, 'ticket_trace/contact': '399, 0'},
#  {'ticket_id': 400, 'ticket_trace/contact': '400-180483, 7'},
#  {'ticket_id': 401, 'ticket_trace/contact': '401, 3'},
#  {'ticket_id': 402,
#   'ticket_trace/contact': '402-11943-33751-70530-81836-157932-245844-321121-362943-423411-465685, 22'},
#  {'ticket_id': 403,
#   'ticket_trace/contact': '403-5699-47039-53187-153835-348074-375581-431208-484876-488273, 17'},
#  {'ticket_id': 404, 'ticket_trace/contact': '404-389774, 2'},
#  {'ticket_id': 405,
#   'ticket_trace/contact': '405-28864-46823-84693-147256-169875-209136-251711-302310-329368-361494-373575-384360-447578-463663, 22'},
#  {'ticket_id': 406, 'ticket_trace/contact': '406, 3'},
#  {'ticket_id': 407, 'ticket_trace/contact': '407-289697-415319, 7'},
#  {'ticket_id': 408, 'ticket_trace/contact': '408-71980, 2'},
#  {'ticket_id': 409,
#   'ticket_trace/contact': '409-1443-24115-32095-67378-82007-199161-203471-213889-215035-238074-326401-345007-412352-468485, 24'},
#  {'ticket_id': 410, 'ticket_trace/contact': '410-239451, 3'},
#  {'ticket_id': 411,
#   'ticket_trace/contact': '411-27210-240255-328377-491794, 6'},
#  {'ticket_id': 412, 'ticket_trace/contact': '412-4731, 3'},
#  {'ticket_id': 413, 'ticket_trace/contact': '413-227511-343113-348366, 11'},
#  {'ticket_id': 414, 'ticket_trace/contact': '414-148438-279759-457089, 6'},
#  {'ticket_id': 415, 'ticket_trace/contact': '415, 4'},
#  {'ticket_id': 416, 'ticket_trace/contact': '376-416-77441-180802-380155, 9'},
#  {'ticket_id': 417, 'ticket_trace/contact': '417-115316-275731, 6'},
#  {'ticket_id': 418, 'ticket_trace/contact': '418-187898-225568, 2'},
#  {'ticket_id': 419,
#   'ticket_trace/contact': '419-42039-118120-118961-124631-264363, 12'},
#  {'ticket_id': 420, 'ticket_trace/contact': '420, 2'},
#  {'ticket_id': 421, 'ticket_trace/contact': '421-114806, 2'},
#  {'ticket_id': 422, 'ticket_trace/contact': '422-418207, 4'},
#  {'ticket_id': 423,
#   'ticket_trace/contact': '423-3049-93058-124282-125187-158447-387779-417980, 12'},
#  {'ticket_id': 424, 'ticket_trace/contact': '424-409260, 1'},
#  {'ticket_id': 425,
#   'ticket_trace/contact': '425-303099-303576-337781-491693, 6'},
#  {'ticket_id': 426, 'ticket_trace/contact': '426, 0'},
#  {'ticket_id': 427, 'ticket_trace/contact': '427, 0'},
#  {'ticket_id': 428,
#   'ticket_trace/contact': '428-92228-135499-298946-477672, 11'},
#  {'ticket_id': 429,
#   'ticket_trace/contact': '429-33819-60658-66412-92028-94191-167056-207117-218669-234261-255817-333625-339352-347082-360345-366596-383684-396170-399331-418173-460551-491203, 43'},
#  {'ticket_id': 430, 'ticket_trace/contact': '430-280037-473852, 9'},
#  {'ticket_id': 431, 'ticket_trace/contact': '431, 1'},
#  {'ticket_id': 432,
#   'ticket_trace/contact': '432-28676-111041-154616-352386-407998, 13'},
#  {'ticket_id': 433,
#   'ticket_trace/contact': '433-123555-169963-232396-238394-373079-389054, 14'},
#  {'ticket_id': 434,
#   'ticket_trace/contact': '434-10732-20159-23427-74870-96491-102021-161740-166747-250836-262859-275394-362287-375317-426557-437946-463639-486755, 30'},
#  {'ticket_id': 435,
#   'ticket_trace/contact': '435-2408-3757-4829-22841-62514-68592-99674-131848-165869-172713-226833-240261-246278-281886-304149-308064-315035-324726-359886-406423-421376-427413-433845-444498-464122-476130-486704-490165, 67'},
#  {'ticket_id': 436, 'ticket_trace/contact': '436, 0'},
#  {'ticket_id': 437, 'ticket_trace/contact': '437, 0'},
#  {'ticket_id': 438, 'ticket_trace/contact': '438-252495, 0'},
#  {'ticket_id': 439,
#   'ticket_trace/contact': '439-60384-85904-89397-180416-215475-314377-349943-436393, 18'},
#  {'ticket_id': 440, 'ticket_trace/contact': '440, 2'},
#  {'ticket_id': 441, 'ticket_trace/contact': '441-17374-407060, 7'},
#  {'ticket_id': 442, 'ticket_trace/contact': '442-331003, 3'},
#  {'ticket_id': 443, 'ticket_trace/contact': '443-11616-252424-396659, 6'},
#  {'ticket_id': 444,
#   'ticket_trace/contact': '444-36170-36286-47700-132601-175482-205249-256797-402930-408997-442357, 23'},
#  {'ticket_id': 445, 'ticket_trace/contact': '445-147951-463753, 8'},
#  {'ticket_id': 446, 'ticket_trace/contact': '446, 1'},
#  {'ticket_id': 447, 'ticket_trace/contact': '447, 0'},
#  {'ticket_id': 448,
#   'ticket_trace/contact': '448-4195-28624-36117-230052-319910, 15'},
#  {'ticket_id': 449, 'ticket_trace/contact': '449-37318, 1'},
#  {'ticket_id': 450, 'ticket_trace/contact': '450, 3'},
#  {'ticket_id': 451, 'ticket_trace/contact': '451-33109-257117, 3'},
#  {'ticket_id': 452, 'ticket_trace/contact': '452-20104, 3'},
#  {'ticket_id': 453,
#   'ticket_trace/contact': '453-614-1067-37425-216954-255726-427041-479976, 9'},
#  {'ticket_id': 454, 'ticket_trace/contact': '454, 0'},
#  {'ticket_id': 455, 'ticket_trace/contact': '455, 0'},
#  {'ticket_id': 456, 'ticket_trace/contact': '456-1927-13912-29763-314678, 11'},
#  {'ticket_id': 457, 'ticket_trace/contact': '457-219497, 6'},
#  {'ticket_id': 458, 'ticket_trace/contact': '458-112268, 6'},
#  {'ticket_id': 459,
#   'ticket_trace/contact': '33-459-46643-117352-269224-499013, 13'},
#  {'ticket_id': 460, 'ticket_trace/contact': '460-332991-361136-487349, 7'},
#  {'ticket_id': 461,
#   'ticket_trace/contact': '461-102737-128188-359210-395991, 8'},
#  {'ticket_id': 462, 'ticket_trace/contact': '462-236650-360242-447282, 9'},
#  {'ticket_id': 463,
#   'ticket_trace/contact': '463-10760-25354-44340-66795-177083-214423-247857-282914-303499-311305-369548-377430-445095, 38'},
#  {'ticket_id': 464, 'ticket_trace/contact': '464-160787-222908-406323, 10'},
#  {'ticket_id': 465,
#   'ticket_trace/contact': '107-465-178290-280212-316970, 12'},
#  {'ticket_id': 466, 'ticket_trace/contact': '466-99430-460410-496986, 10'},
#  {'ticket_id': 467,
#   'ticket_trace/contact': '467-28326-57955-62041-77440-102257-226362-258846-328582, 13'},
#  {'ticket_id': 468, 'ticket_trace/contact': '468-25546-189982-310021, 8'},
#  {'ticket_id': 469, 'ticket_trace/contact': '469, 2'},
#  {'ticket_id': 470, 'ticket_trace/contact': '470, 4'},
#  {'ticket_id': 471, 'ticket_trace/contact': '471-235070, 3'},
#  {'ticket_id': 472, 'ticket_trace/contact': '472, 4'},
#  {'ticket_id': 473, 'ticket_trace/contact': '473-193388-446441, 10'},
#  {'ticket_id': 474, 'ticket_trace/contact': '474, 2'},
#  {'ticket_id': 475, 'ticket_trace/contact': '475, 0'},
#  {'ticket_id': 476, 'ticket_trace/contact': '476, 2'},
#  {'ticket_id': 477, 'ticket_trace/contact': '477-323356, 4'},
#  {'ticket_id': 478, 'ticket_trace/contact': '478-21965-31756-162693, 5'},
#  {'ticket_id': 479, 'ticket_trace/contact': '479-375311-411153, 3'},
#  {'ticket_id': 480,
#   'ticket_trace/contact': '480-5741-22455-192208-287876-338096-358072-462278-493854-499059, 27'},
#  {'ticket_id': 481, 'ticket_trace/contact': '481, 4'},
#  {'ticket_id': 482, 'ticket_trace/contact': '482-314173, 8'},
#  {'ticket_id': 483, 'ticket_trace/contact': '483-86872-388949-438463, 11'},
#  {'ticket_id': 484, 'ticket_trace/contact': '484-307287, 4'},
#  {'ticket_id': 485, 'ticket_trace/contact': '485, 0'},
#  {'ticket_id': 486, 'ticket_trace/contact': '486, 2'},
#  {'ticket_id': 487,
#   'ticket_trace/contact': '487-49612-81565-157448-475966, 13'},
#  {'ticket_id': 488,
#   'ticket_trace/contact': '488-11777-13531-79149-229409-305072-359626, 10'},
#  {'ticket_id': 489, 'ticket_trace/contact': '489, 3'},
#  {'ticket_id': 490, 'ticket_trace/contact': '490-159196, 4'},
#  {'ticket_id': 491, 'ticket_trace/contact': '491-313193-338161-350000, 6'},
#  {'ticket_id': 492,
#   'ticket_trace/contact': '492-11635-24611-273094-340286, 16'},
#  {'ticket_id': 493,
#   'ticket_trace/contact': '493-81681-127177-240528-302741, 4'},
#  {'ticket_id': 494, 'ticket_trace/contact': '494, 1'},
#  {'ticket_id': 495, 'ticket_trace/contact': '495, 3'},
#  {'ticket_id': 496, 'ticket_trace/contact': '496, 0'},
#  {'ticket_id': 497, 'ticket_trace/contact': '497-141929, 3'},
#  {'ticket_id': 498, 'ticket_trace/contact': '498-45940-374447-376465, 8'},
#  {'ticket_id': 499, 'ticket_trace/contact': '499, 4'},
#  {'ticket_id': 500, 'ticket_trace/contact': '500-41473-131552, 6'},
#  {'ticket_id': 501, 'ticket_trace/contact': '501, 1'},
#  {'ticket_id': 502,
#   'ticket_trace/contact': '502-327256-351258-353206-381138-392235, 7'},
#  {'ticket_id': 503, 'ticket_trace/contact': '503-60670-179927-417856, 8'},
#  {'ticket_id': 504, 'ticket_trace/contact': '504-300586, 2'},
#  {'ticket_id': 505, 'ticket_trace/contact': '505, 2'},
#  {'ticket_id': 506, 'ticket_trace/contact': '506, 0'},
#  {'ticket_id': 507, 'ticket_trace/contact': '507-191670-347502-456667, 12'},
#  {'ticket_id': 508, 'ticket_trace/contact': '508-190545, 4'},
#  {'ticket_id': 509, 'ticket_trace/contact': '509-20781-174724, 4'},
#  {'ticket_id': 510, 'ticket_trace/contact': '510-346427, 6'},
#  {'ticket_id': 511, 'ticket_trace/contact': '511-188228, 5'},
#  {'ticket_id': 512, 'ticket_trace/contact': '512, 1'},
#  {'ticket_id': 513, 'ticket_trace/contact': '513, 4'},
#  {'ticket_id': 514,
#   'ticket_trace/contact': '514-39575-230363-434667-477945, 13'},
#  {'ticket_id': 515, 'ticket_trace/contact': '515-164569-289232, 2'},
#  {'ticket_id': 516, 'ticket_trace/contact': '516-467155, 3'},
#  {'ticket_id': 517,
#   'ticket_trace/contact': '517-64638-161035-285274-306324-323452-372323-376413, 16'},
#  {'ticket_id': 518, 'ticket_trace/contact': '518-413056, 4'},
#  {'ticket_id': 519, 'ticket_trace/contact': '519, 3'},
#  {'ticket_id': 520, 'ticket_trace/contact': '520, 4'},
#  {'ticket_id': 521, 'ticket_trace/contact': '521-209133, 3'},
#  {'ticket_id': 522, 'ticket_trace/contact': '522-448567, 4'},
#  {'ticket_id': 523, 'ticket_trace/contact': '523, 0'},
#  {'ticket_id': 524,
#   'ticket_trace/contact': '524-151737-236099-418280-435462, 16'},
#  {'ticket_id': 525, 'ticket_trace/contact': '525-145035-276217, 9'},
#  {'ticket_id': 526,
#   'ticket_trace/contact': '526-1227-22224-29530-41961-97082-122596-324814-330206-456235, 18'},
#  {'ticket_id': 527, 'ticket_trace/contact': '527, 4'},
#  {'ticket_id': 528,
#   'ticket_trace/contact': '528-217217-249033-271971-360868, 15'},
#  {'ticket_id': 529, 'ticket_trace/contact': '529-429313, 8'},
#  {'ticket_id': 530, 'ticket_trace/contact': '530, 4'},
#  {'ticket_id': 531, 'ticket_trace/contact': '531-404051, 7'},
#  {'ticket_id': 532, 'ticket_trace/contact': '532, 2'},
#  {'ticket_id': 533, 'ticket_trace/contact': '533-217340-420800-493102, 8'},
#  {'ticket_id': 534, 'ticket_trace/contact': '534-20490-402455-423806, 10'},
#  {'ticket_id': 535,
#   'ticket_trace/contact': '535-55549-152814-206314-285141-366713-412817-423593-481349-496518, 22'},
#  {'ticket_id': 536, 'ticket_trace/contact': '536-181541, 2'},
#  {'ticket_id': 537, 'ticket_trace/contact': '537-9822-129071, 9'},
#  {'ticket_id': 538, 'ticket_trace/contact': '538-206101-239171-495924, 14'},
#  {'ticket_id': 539,
#   'ticket_trace/contact': '539-35136-47267-80631-235689-253369-273994, 8'},
#  {'ticket_id': 540,
#   'ticket_trace/contact': '540-1604-7020-35672-43011-80757-135340-165012-210385-242184-267176-303489-359402-390985-399688-416069-431063, 28'},
#  {'ticket_id': 541, 'ticket_trace/contact': '541-178994, 2'},
#  {'ticket_id': 542, 'ticket_trace/contact': '542-28928-127112-236528, 6'},
#  {'ticket_id': 543, 'ticket_trace/contact': '543-26943-411938, 6'},
#  {'ticket_id': 544, 'ticket_trace/contact': '544, 0'},
#  {'ticket_id': 545, 'ticket_trace/contact': '545, 3'},
#  {'ticket_id': 546,
#   'ticket_trace/contact': '546-14176-379370-407625-484124, 12'},
#  {'ticket_id': 547,
#   'ticket_trace/contact': '547-141214-158946-167193-182754-229438-254240-255004-286886-331327-469314, 18'},
#  {'ticket_id': 548, 'ticket_trace/contact': '548, 4'},
#  {'ticket_id': 549, 'ticket_trace/contact': '549-225394-263288, 5'},
#  {'ticket_id': 550, 'ticket_trace/contact': '550-36763-462470, 10'},
#  {'ticket_id': 551, 'ticket_trace/contact': '551, 2'},
#  {'ticket_id': 552, 'ticket_trace/contact': '552-248397, 0'},
#  {'ticket_id': 553, 'ticket_trace/contact': '553, 4'},
#  {'ticket_id': 554, 'ticket_trace/contact': '554, 0'},
#  {'ticket_id': 555, 'ticket_trace/contact': '555-1295-405463, 5'},
#  {'ticket_id': 556, 'ticket_trace/contact': '556-162407, 6'},
#  {'ticket_id': 557,
#   'ticket_trace/contact': '557-21830-27438-181639-253736-346507-410792, 22'},
#  {'ticket_id': 558,
#   'ticket_trace/contact': '558-150016-160938-165823-384630-396462-399433-427734-480272, 14'},
#  {'ticket_id': 559,
#   'ticket_trace/contact': '205-559-850-51845-215655-252724-354483-372904-465114, 24'},
#  {'ticket_id': 560, 'ticket_trace/contact': '560-190564, 5'},
#  {'ticket_id': 561, 'ticket_trace/contact': '561-252769, 5'},
#  {'ticket_id': 562, 'ticket_trace/contact': '562, 3'},
#  {'ticket_id': 563, 'ticket_trace/contact': '563, 0'},
#  {'ticket_id': 564, 'ticket_trace/contact': '564-3291-489868, 7'},
#  {'ticket_id': 565,
#   'ticket_trace/contact': '565-34215-44561-94948-114997-164495-165069-170375-200225-200917-244188-341108-371250-397849, 23'},
#  {'ticket_id': 566, 'ticket_trace/contact': '566, 2'},
#  {'ticket_id': 567,
#   'ticket_trace/contact': '567-292433-413290-435817-495350, 3'},
#  {'ticket_id': 568, 'ticket_trace/contact': '568-13659-85792, 4'},
#  {'ticket_id': 569, 'ticket_trace/contact': '569-321785, 6'},
#  {'ticket_id': 570, 'ticket_trace/contact': '570-74358-364222, 2'},
#  {'ticket_id': 571,
#   'ticket_trace/contact': '571-27743-97997-117686-151346-188477-336615-451034, 14'},
#  {'ticket_id': 572, 'ticket_trace/contact': '572, 3'},
#  {'ticket_id': 573, 'ticket_trace/contact': '573, 0'},
#  {'ticket_id': 574,
#   'ticket_trace/contact': '574-624-15494-20248-28672-184721-300273-302155-330799-372761-375542-447379, 26'},
#  {'ticket_id': 575, 'ticket_trace/contact': '575, 3'},
#  {'ticket_id': 576,
#   'ticket_trace/contact': '576-62127-114122-266855-293698-364332-384088, 13'},
#  {'ticket_id': 577, 'ticket_trace/contact': '577, 2'},
#  {'ticket_id': 578, 'ticket_trace/contact': '578-343978, 7'},
#  {'ticket_id': 579, 'ticket_trace/contact': '579-115513-218817-420803, 10'},
#  {'ticket_id': 580, 'ticket_trace/contact': '580-95331-146464-401293, 10'},
#  {'ticket_id': 581, 'ticket_trace/contact': '581-261099, 0'},
#  {'ticket_id': 582,
#   'ticket_trace/contact': '582-15568-40271-427696-429996-440919-476928, 20'},
#  {'ticket_id': 583, 'ticket_trace/contact': '583, 4'},
#  {'ticket_id': 584, 'ticket_trace/contact': '584-385073, 7'},
#  {'ticket_id': 585,
#   'ticket_trace/contact': '585-10471-167525-194684-259784-363786, 7'},
#  {'ticket_id': 586, 'ticket_trace/contact': '586-79310, 2'},
#  {'ticket_id': 587, 'ticket_trace/contact': '587, 4'},
#  {'ticket_id': 588, 'ticket_trace/contact': '588-90011-295197-485695, 15'},
#  {'ticket_id': 589, 'ticket_trace/contact': '589, 0'},
#  {'ticket_id': 590, 'ticket_trace/contact': '590-343089, 6'},
#  {'ticket_id': 591, 'ticket_trace/contact': '591, 4'},
#  {'ticket_id': 592, 'ticket_trace/contact': '592-306360-412630, 8'},
#  {'ticket_id': 593, 'ticket_trace/contact': '593, 0'},
#  {'ticket_id': 594, 'ticket_trace/contact': '594-28339, 2'},
#  {'ticket_id': 595, 'ticket_trace/contact': '595-158229-191199-358811, 12'},
#  {'ticket_id': 596, 'ticket_trace/contact': '596-356634, 4'},
#  {'ticket_id': 597, 'ticket_trace/contact': '597-382548-480264, 1'},
#  {'ticket_id': 598,
#   'ticket_trace/contact': '598-26848-106085-118727-184551-260822-267012-291735-302324-346043-440431, 23'},
#  {'ticket_id': 599,
#   'ticket_trace/contact': '599-34194-70484-88474-180896-265284-395886, 14'},
#  {'ticket_id': 600, 'ticket_trace/contact': '600-338672, 6'},
#  {'ticket_id': 601,
#   'ticket_trace/contact': '601-102708-134000-241487-247549-270484-300025-333961-335261-382583-398979-403870-409751-423274-450425, 37'},
#  {'ticket_id': 602, 'ticket_trace/contact': '602-5410, 5'},
#  {'ticket_id': 603,
#   'ticket_trace/contact': '603-5623-8683-69427-70967-141248-159549-160277-193937-241546-311348-348895-360750-414571-497689, 38'},
#  {'ticket_id': 604, 'ticket_trace/contact': '604-436665, 4'},
#  {'ticket_id': 605, 'ticket_trace/contact': '605-227309, 7'},
#  {'ticket_id': 606, 'ticket_trace/contact': '606-327210-485559, 7'},
#  {'ticket_id': 607,
#   'ticket_trace/contact': '607-34143-48181-68949-148910-262318-317815-361259-365417-391531-433188-439827-455700-485486-491028-492331, 35'},
#  {'ticket_id': 608, 'ticket_trace/contact': '608-141892, 3'},
#  {'ticket_id': 609, 'ticket_trace/contact': '609-52574-175015, 4'},
#  {'ticket_id': 610, 'ticket_trace/contact': '610-203549, 4'},
#  {'ticket_id': 611, 'ticket_trace/contact': '611, 3'},
#  {'ticket_id': 612, 'ticket_trace/contact': '612-222027, 8'},
#  {'ticket_id': 613, 'ticket_trace/contact': '613-10373-16584-265652, 6'},
#  {'ticket_id': 614,
#   'ticket_trace/contact': '453-614-1067-37425-216954-255726-427041-479976, 9'},
#  {'ticket_id': 615,
#   'ticket_trace/contact': '615-935-156756-170720-396128, 12'},
#  {'ticket_id': 616, 'ticket_trace/contact': '616, 4'},
#  {'ticket_id': 617,
#   'ticket_trace/contact': '617-43717-45046-56604-123798-131466-220355-251693-302555-344922-412904-466579, 21'},
#  {'ticket_id': 618, 'ticket_trace/contact': '618, 2'},
#  {'ticket_id': 619, 'ticket_trace/contact': '619-238610, 8'},
#  {'ticket_id': 620, 'ticket_trace/contact': '620, 1'},
#  {'ticket_id': 621, 'ticket_trace/contact': '621-17884-330172, 8'},
#  {'ticket_id': 622,
#   'ticket_trace/contact': '622-2793-93152-97107-287024-346662, 8'},
#  {'ticket_id': 623, 'ticket_trace/contact': '623-5637-403088, 7'},
#  {'ticket_id': 624,
#   'ticket_trace/contact': '574-624-15494-20248-28672-184721-300273-302155-330799-372761-375542-447379, 26'},
#  {'ticket_id': 625,
#   'ticket_trace/contact': '625-41299-96928-392684-447398, 19'},
#  {'ticket_id': 626, 'ticket_trace/contact': '626-153127-432385-442144, 9'},
#  {'ticket_id': 627, 'ticket_trace/contact': '627, 1'},
#  {'ticket_id': 628, 'ticket_trace/contact': '628, 2'},
#  {'ticket_id': 629, 'ticket_trace/contact': '629-27809-252223-252689, 8'},
#  {'ticket_id': 630, 'ticket_trace/contact': '630-256442, 0'},
#  {'ticket_id': 631, 'ticket_trace/contact': '631, 1'},
#  {'ticket_id': 632, 'ticket_trace/contact': '632-145714-295141, 8'},
#  {'ticket_id': 633, 'ticket_trace/contact': '633-327156-355912-472010, 8'},
#  {'ticket_id': 634, 'ticket_trace/contact': '634-449538, 1'},
#  {'ticket_id': 635, 'ticket_trace/contact': '635, 0'},
# ...
#  {'ticket_id': 793,
#   'ticket_trace/contact': '793-4216-4778-7255-11813-37997-123548-297430, 8'},
#  {'ticket_id': 794,
#   'ticket_trace/contact': '794-193750-196464-302588-452583, 4'},
#  {'ticket_id': 795,
#   'ticket_trace/contact': '795-18329-21092-189966-237086-247526-259344-331625-358233-368457-418844-419490, 18'},
#  {'ticket_id': 796, 'ticket_trace/contact': '796-8694, 2'},
#  {'ticket_id': 797, 'ticket_trace/contact': '797, 2'},
#  {'ticket_id': 798,
#   'ticket_trace/contact': '798-66857-97226-98923-113053-168283-202538-219430-227835-284997-309925-330381-360408-394885-488105-498089, 25'},
#  {'ticket_id': 799, 'ticket_trace/contact': '799-444043, 8'},
#  {'ticket_id': 800, 'ticket_trace/contact': '800-372337, 1'},
#  {'ticket_id': 801,
#   'ticket_trace/contact': '249-801-30407-329017-337064-442715, 10'},
#  {'ticket_id': 802, 'ticket_trace/contact': '802, 4'},
#  {'ticket_id': 803,
#   'ticket_trace/contact': '803-33736-69748-73744-129820-222328-297516-433626, 17'},
#  {'ticket_id': 804, 'ticket_trace/contact': '804-1409-92356, 2'},
#  {'ticket_id': 805,
#   'ticket_trace/contact': '805-19158-212028-215306-252791-279033-283459-304437-375544-417285-471239, 21'},
#  {'ticket_id': 806, 'ticket_trace/contact': '806-33248-261237, 4'},
#  {'ticket_id': 807,
#   'ticket_trace/contact': '807-103671-113413-151799-232673-271216, 8'},
#  {'ticket_id': 808, 'ticket_trace/contact': '808-26145-80654-392586, 7'},
#  {'ticket_id': 809, 'ticket_trace/contact': '809-222814, 5'},
#  {'ticket_id': 810, 'ticket_trace/contact': '810, 2'},
#  {'ticket_id': 811, 'ticket_trace/contact': '811-13927, 4'},
#  {'ticket_id': 812,
#   'ticket_trace/contact': '812-5387-49878-76242-85737-237353-245704-277648-384277-429717-473682, 20'},
#  {'ticket_id': 813, 'ticket_trace/contact': '813, 2'},
#  {'ticket_id': 814,
#   'ticket_trace/contact': '814-217893-255008-355860-421890-480435, 19'},
#  {'ticket_id': 815, 'ticket_trace/contact': '815-479618, 4'},
#  {'ticket_id': 816, 'ticket_trace/contact': '816-437332, 5'},
#  {'ticket_id': 817, 'ticket_trace/contact': '224-817-51435-316595, 8'},
#  {'ticket_id': 818,
#   'ticket_trace/contact': '818-18604-38062-87223-133703-427781, 13'},
#  {'ticket_id': 819, 'ticket_trace/contact': '819-5312-83650-250070, 7'},
#  {'ticket_id': 820, 'ticket_trace/contact': '820-192942-405436, 11'},
#  {'ticket_id': 821, 'ticket_trace/contact': '821-164378-389158-436758, 5'},
#  {'ticket_id': 822,
#   'ticket_trace/contact': '100-822-1157-79530-95287-109959-129043-146402-181117-205684-220328-280716-282502-306045-379958-437044-451994-475973, 38'},
#  {'ticket_id': 823, 'ticket_trace/contact': '823-20646-38058-261205, 6'},
#  {'ticket_id': 824, 'ticket_trace/contact': '824, 2'},
#  {'ticket_id': 825,
#   'ticket_trace/contact': '825-53095-55719-74001-96470-103914-132510-164916-242776-271799-282995-410648, 26'},
#  {'ticket_id': 826, 'ticket_trace/contact': '826, 4'},
#  {'ticket_id': 827, 'ticket_trace/contact': '827-19090-163233-332959, 1'},
#  {'ticket_id': 828,
#   'ticket_trace/contact': '828-30372-59266-202747-246452-353396, 17'},
#  {'ticket_id': 829, 'ticket_trace/contact': '829, 3'},
#  {'ticket_id': 830, 'ticket_trace/contact': '830, 2'},
#  {'ticket_id': 831, 'ticket_trace/contact': '831-112693, 4'},
#  {'ticket_id': 832, 'ticket_trace/contact': '832-287088-409696, 6'},
#  {'ticket_id': 833, 'ticket_trace/contact': '833, 4'},
#  {'ticket_id': 834, 'ticket_trace/contact': '834, 2'},
#  {'ticket_id': 835,
#   'ticket_trace/contact': '835-31206-91634-97029-146824-153094-178926-196161-256619-265463-270386-280459-321044-364242-408723-420889-439754-447146-455026-488361-493567, 48'},
#  {'ticket_id': 836, 'ticket_trace/contact': '836-295363, 7'},
#  {'ticket_id': 837, 'ticket_trace/contact': '837-187903, 7'},
#  {'ticket_id': 838, 'ticket_trace/contact': '838-40189, 4'},
#  {'ticket_id': 839, 'ticket_trace/contact': '839, 0'},
#  {'ticket_id': 840, 'ticket_trace/contact': '840, 3'},
#  {'ticket_id': 841, 'ticket_trace/contact': '841, 2'},
#  {'ticket_id': 842, 'ticket_trace/contact': '842, 2'},
#  {'ticket_id': 843, 'ticket_trace/contact': '843, 1'},
#  {'ticket_id': 844,
#   'ticket_trace/contact': '844-17292-193726-227264-283873-314011, 11'},
#  {'ticket_id': 845, 'ticket_trace/contact': '845, 1'},
#  {'ticket_id': 846, 'ticket_trace/contact': '846-410835, 7'},
#  {'ticket_id': 847, 'ticket_trace/contact': '847-427722, 3'},
#  {'ticket_id': 848,
#   'ticket_trace/contact': '848-10216-108030-170282-232653-306236-439476, 9'},
#  {'ticket_id': 849, 'ticket_trace/contact': '849-60766, 7'},
#  {'ticket_id': 850,
#   'ticket_trace/contact': '205-559-850-51845-215655-252724-354483-372904-465114, 24'},
#  {'ticket_id': 851, 'ticket_trace/contact': '851, 2'},
#  {'ticket_id': 852, 'ticket_trace/contact': '852, 2'},
#  {'ticket_id': 853,
#   'ticket_trace/contact': '853-35528-132780-137819-185535-215106-222826-230940-238195-259660-301043-365506-414974-459933-490066, 32'},
#  {'ticket_id': 854,
#   'ticket_trace/contact': '854-1387-16071-34233-35471-58580-75699-88129-109102-111470-121868-155378-160740-211141-237283-242098-280273-286862-311058-318602-351923-414231-427288-432456-450432-491478-493537, 52'},
#  {'ticket_id': 855, 'ticket_trace/contact': '855-458602, 1'},
#  {'ticket_id': 856,
#   'ticket_trace/contact': '106-856-164892-298789-478387-494415, 6'},
#  {'ticket_id': 857,
#   'ticket_trace/contact': '857-43238-126849-173635-311250-353031-410571-482122, 20'},
#  {'ticket_id': 858, 'ticket_trace/contact': '858-304837-335707, 6'},
#  {'ticket_id': 859,
#   'ticket_trace/contact': '859-129749-365616-377241-470659-471176, 10'},
#  {'ticket_id': 860, 'ticket_trace/contact': '860-19766, 2'},
#  {'ticket_id': 861, 'ticket_trace/contact': '861, 4'},
#  {'ticket_id': 862, 'ticket_trace/contact': '862, 0'},
#  {'ticket_id': 863,
#   'ticket_trace/contact': '863-142003-153098-255513-340869-359695-392063-408383-467986-484461-498095, 27'},
#  {'ticket_id': 864, 'ticket_trace/contact': '864, 3'},
#  {'ticket_id': 865, 'ticket_trace/contact': '865-395308, 2'},
#  {'ticket_id': 866, 'ticket_trace/contact': '866-10039, 3'},
#  {'ticket_id': 867, 'ticket_trace/contact': '867-352790, 5'},
#  {'ticket_id': 868, 'ticket_trace/contact': '868, 0'},
#  {'ticket_id': 869, 'ticket_trace/contact': '869, 3'},
#  {'ticket_id': 870, 'ticket_trace/contact': '870-39678-437741, 8'},
#  {'ticket_id': 871, 'ticket_trace/contact': '871, 2'},
#  {'ticket_id': 872,
#   'ticket_trace/contact': '872-52930-67350-79347-80881-136676-177833-218424-248349-256734-287074-297946-341586-359821-454865-463771-480712, 30'},
#  {'ticket_id': 873, 'ticket_trace/contact': '873-461485, 4'},
#  {'ticket_id': 874,
#   'ticket_trace/contact': '874-19251-257292-272505-394370-414830-432686, 14'},
#  {'ticket_id': 875, 'ticket_trace/contact': '875-126635-261093-299527, 6'},
#  {'ticket_id': 876, 'ticket_trace/contact': '876, 0'},
#  {'ticket_id': 877, 'ticket_trace/contact': '877, 1'},
#  {'ticket_id': 878, 'ticket_trace/contact': '878-86564-195038-489395, 6'},
#  {'ticket_id': 879, 'ticket_trace/contact': '879-288383-371490, 6'},
#  {'ticket_id': 880,
#   'ticket_trace/contact': '880-7518-7764-11375-16637-17880-26359-34258-37254-58212-59380-61313-67537-88784-100003-106771-114955-130712-149251-160672-176430-179377-215844-225434-232435-245510-291641-300693-336285-359175-362758-363982-405120-409545-412736-430500-438982-459690-465474-474111, 81'},
#  {'ticket_id': 881, 'ticket_trace/contact': '881, 1'},
#  {'ticket_id': 882,
#   'ticket_trace/contact': '882-11327-35991-55354-68419-74424-119017-153364-269030-302670-320160-347879-391844-456052, 23'},
#  {'ticket_id': 883, 'ticket_trace/contact': '883-6894-189625-258378, 12'},
#  {'ticket_id': 884,
#   'ticket_trace/contact': '884-43302-128007-246993-269310-289237-361797-424295-476828-498423, 19'},
#  {'ticket_id': 885, 'ticket_trace/contact': '885, 2'},
#  {'ticket_id': 886, 'ticket_trace/contact': '886, 3'},
#  {'ticket_id': 887, 'ticket_trace/contact': '887-241650, 5'},
#  {'ticket_id': 888, 'ticket_trace/contact': '888-18276-112339, 9'},
#  {'ticket_id': 889,
#   'ticket_trace/contact': '889-108566-231042-263437-343180-391231-429795, 17'},
#  {'ticket_id': 890,
#   'ticket_trace/contact': '890-97827-126964-128176-438897, 11'},
#  {'ticket_id': 891, 'ticket_trace/contact': '891-76694, 2'},
#  {'ticket_id': 892, 'ticket_trace/contact': '892-60020-467624, 2'},
#  {'ticket_id': 893, 'ticket_trace/contact': '893, 0'},
#  {'ticket_id': 894, 'ticket_trace/contact': '894-455109, 3'},
#  {'ticket_id': 895, 'ticket_trace/contact': '895, 0'},
#  {'ticket_id': 896, 'ticket_trace/contact': '896-273058-449813, 7'},
#  {'ticket_id': 897, 'ticket_trace/contact': '897-39037-118450-412156, 8'},
#  {'ticket_id': 898, 'ticket_trace/contact': '898, 1'},
#  {'ticket_id': 899, 'ticket_trace/contact': '899-100639-170882, 5'},
#  {'ticket_id': 900, 'ticket_trace/contact': '900-81561, 3'},
#  {'ticket_id': 901, 'ticket_trace/contact': '901-104190-317983, 10'},
#  {'ticket_id': 902, 'ticket_trace/contact': '902-7274-157844, 6'},
#  {'ticket_id': 903, 'ticket_trace/contact': '903-30314, 3'},
#  {'ticket_id': 904, 'ticket_trace/contact': '904-22100-64357-139132, 7'},
#  {'ticket_id': 905, 'ticket_trace/contact': '905, 3'},
#  {'ticket_id': 906, 'ticket_trace/contact': '906, 3'},
#  {'ticket_id': 907, 'ticket_trace/contact': '907-453456, 1'},
#  {'ticket_id': 908, 'ticket_trace/contact': '908-116482-139397-164972, 11'},
#  {'ticket_id': 909, 'ticket_trace/contact': '909-1255-38284-96626-464474, 11'},
#  {'ticket_id': 910, 'ticket_trace/contact': '910-126531-288087-433736, 12'},
#  {'ticket_id': 911, 'ticket_trace/contact': '911, 0'},
#  {'ticket_id': 912,
#   'ticket_trace/contact': '912-145246-179220-481484-488385, 6'},
#  {'ticket_id': 913,
#   'ticket_trace/contact': '913-3904-3991-86121-205282-215696-219270-237665, 17'},
#  {'ticket_id': 914, 'ticket_trace/contact': '914, 4'},
#  {'ticket_id': 915, 'ticket_trace/contact': '915, 0'},
#  {'ticket_id': 916, 'ticket_trace/contact': '916-439740, 4'},
#  {'ticket_id': 917, 'ticket_trace/contact': '917-422985, 6'},
#  {'ticket_id': 918, 'ticket_trace/contact': '918-244409, 1'},
#  {'ticket_id': 919,
#   'ticket_trace/contact': '919-8550-136067-255800-261816, 11'},
#  {'ticket_id': 920, 'ticket_trace/contact': '920, 1'},
#  {'ticket_id': 921, 'ticket_trace/contact': '921-376585-444459, 4'},
#  {'ticket_id': 922, 'ticket_trace/contact': '922-249994, 6'},
#  {'ticket_id': 923, 'ticket_trace/contact': '923, 1'},
#  {'ticket_id': 924, 'ticket_trace/contact': '924-61937-109486-267326, 5'},
#  {'ticket_id': 925, 'ticket_trace/contact': '925-16251-429534, 5'},
#  {'ticket_id': 926, 'ticket_trace/contact': '926-32156-431788, 4'},
#  {'ticket_id': 927,
#   'ticket_trace/contact': '927-5227-10415-24381-31886-41021-42947-62704-109890-121427-156582-165693-194112-220409-231434-297737-323684-338762-351247-396970-409302-412669-483337-496168, 53'},
#  {'ticket_id': 928, 'ticket_trace/contact': '928, 1'},
#  {'ticket_id': 929, 'ticket_trace/contact': '929, 2'},
#  {'ticket_id': 930, 'ticket_trace/contact': '930, 2'},
#  {'ticket_id': 931, 'ticket_trace/contact': '931, 1'},
#  {'ticket_id': 932, 'ticket_trace/contact': '932, 3'},
#  {'ticket_id': 933, 'ticket_trace/contact': '933-7168-358304-449522, 11'},
#  {'ticket_id': 934, 'ticket_trace/contact': '934, 2'},
#  {'ticket_id': 935,
#   'ticket_trace/contact': '615-935-156756-170720-396128, 12'},
#  {'ticket_id': 936, 'ticket_trace/contact': '936, 1'},
#  {'ticket_id': 937,
#   'ticket_trace/contact': '164-937-1259-1610-12101-14883-56600-57027-76148-110666-145523-160154-282091-411076-477605, 32'},
#  {'ticket_id': 938, 'ticket_trace/contact': '938-340564, 6'},
#  {'ticket_id': 939,
#   'ticket_trace/contact': '939-59940-129428-169152-380751-453147-465194, 13'},
#  {'ticket_id': 940, 'ticket_trace/contact': '940-18536-495306, 4'},
#  {'ticket_id': 941,
#   'ticket_trace/contact': '941-82277-179963-345507-429157-446784, 15'},
#  {'ticket_id': 942, 'ticket_trace/contact': '942, 2'},
#  {'ticket_id': 943, 'ticket_trace/contact': '943-257446-296970, 3'},
#  {'ticket_id': 944, 'ticket_trace/contact': '944-123018-456280-479350, 6'},
#  {'ticket_id': 945, 'ticket_trace/contact': '945-114540, 4'},
#  {'ticket_id': 946, 'ticket_trace/contact': '946-152515, 7'},
#  {'ticket_id': 947,
#   'ticket_trace/contact': '947-30990-44620-50530-237238-239507, 10'},
#  {'ticket_id': 948, 'ticket_trace/contact': '948-270949, 3'},
#  {'ticket_id': 949, 'ticket_trace/contact': '949, 3'},
#  {'ticket_id': 950,
#   'ticket_trace/contact': '950-1479-10902-210605-227087-279738-291586-383323-409970, 23'},
#  {'ticket_id': 951, 'ticket_trace/contact': '951-218717-341555-405270, 7'},
#  {'ticket_id': 952, 'ticket_trace/contact': '952-482702, 4'},
#  {'ticket_id': 953,
#   'ticket_trace/contact': '953-100893-143552-151550-205140-234473-293187-297180-353282-483338-492764, 29'},
#  {'ticket_id': 954, 'ticket_trace/contact': '954, 1'},
#  {'ticket_id': 955, 'ticket_trace/contact': '955-258019-404288, 4'},
#  {'ticket_id': 956, 'ticket_trace/contact': '956-12279-118604, 3'},
#  {'ticket_id': 957,
#   'ticket_trace/contact': '957-138680-249248-268233-373900-491648, 8'},
#  {'ticket_id': 958,
#   'ticket_trace/contact': '958-42168-44071-59420-72274-83363-102796-114387-119887-227272-268019-302983-329934-349543-455436-463893, 28'},
#  {'ticket_id': 959, 'ticket_trace/contact': '959, 0'},
#  {'ticket_id': 960, 'ticket_trace/contact': '960-247253, 4'},
#  {'ticket_id': 961, 'ticket_trace/contact': '961, 0'},
#  {'ticket_id': 962, 'ticket_trace/contact': '962, 4'},
#  {'ticket_id': 963, 'ticket_trace/contact': '963, 0'},
#  {'ticket_id': 964, 'ticket_trace/contact': '964-13953-281484, 6'},
#  {'ticket_id': 965, 'ticket_trace/contact': '965, 4'},
#  {'ticket_id': 966, 'ticket_trace/contact': '966, 2'},
#  {'ticket_id': 967,
#   'ticket_trace/contact': '967-64910-140597-208715-268516-298014-460088, 13'},
#  {'ticket_id': 968, 'ticket_trace/contact': '968-36371, 4'},
#  {'ticket_id': 969, 'ticket_trace/contact': '969-20692-33446, 3'},
#  {'ticket_id': 970,
#   'ticket_trace/contact': '970-11481-175497-313830-494495, 15'},
#  {'ticket_id': 971,
#   'ticket_trace/contact': '971-2890-158299-311659-359073-470681-499923, 16'},
#  {'ticket_id': 972,
#   'ticket_trace/contact': '972-26395-66188-75443-114914-209335-275495-302572-326000-371404-386125-426836-453002-463202-484081-488567, 26'},
#  {'ticket_id': 973, 'ticket_trace/contact': '973, 1'},
#  {'ticket_id': 974, 'ticket_trace/contact': '974-468707, 4'},
#  {'ticket_id': 975, 'ticket_trace/contact': '975, 4'},
#  {'ticket_id': 976,
#   'ticket_trace/contact': '976-75287-141996-148164-252077-270360-384338-491221, 13'},
#  {'ticket_id': 977, 'ticket_trace/contact': '977, 4'},
#  {'ticket_id': 978,
#   'ticket_trace/contact': '978-52331-149879-225579-303480-486790-492578, 19'},
#  {'ticket_id': 979,
#   'ticket_trace/contact': '979-5698-21667-150740-151788-162138-183153-209426-296260-340064-409339-416878-492293, 30'},
#  {'ticket_id': 980, 'ticket_trace/contact': '980-93879, 1'},
#  {'ticket_id': 981,
#   'ticket_trace/contact': '981-2895-3859-36429-71682-97485-113575-197744-227697-251588-258544-272022-307361-309505-469842, 29'},
#  {'ticket_id': 982, 'ticket_trace/contact': '982, 3'},
#  {'ticket_id': 983, 'ticket_trace/contact': '983, 0'},
#  {'ticket_id': 984, 'ticket_trace/contact': '984, 1'},
#  {'ticket_id': 985, 'ticket_trace/contact': '985, 4'},
#  {'ticket_id': 986, 'ticket_trace/contact': '986, 3'},
#  {'ticket_id': 987, 'ticket_trace/contact': '987, 0'},
#  {'ticket_id': 988, 'ticket_trace/contact': '988-285906, 4'},
#  {'ticket_id': 989,
#   'ticket_trace/contact': '989-158990-225789-375182-455559, 13'},
#  {'ticket_id': 990, 'ticket_trace/contact': '990, 2'},
#  {'ticket_id': 991,
#   'ticket_trace/contact': '991-2944-141480-262252-496087, 7'},
#  {'ticket_id': 992,
#   'ticket_trace/contact': '992-27166-97073-129495-293629-359275-368404-396869-420105, 17'},
#  {'ticket_id': 993, 'ticket_trace/contact': '993-83513-146500, 6'},
#  {'ticket_id': 994, 'ticket_trace/contact': '994, 2'},
#  {'ticket_id': 995, 'ticket_trace/contact': '995-316304-341113, 8'},
#  {'ticket_id': 996, 'ticket_trace/contact': '996-3500, 5'},
#  {'ticket_id': 997, 'ticket_trace/contact': '997, 2'},
#  {'ticket_id': 998, 'ticket_trace/contact': '998-78821-387554, 6'},
#  {'ticket_id': 999, 'ticket_trace/contact': '999, 2'},
#  ...]

# %%
output_df = pd.DataFrame(output)
output_df
# Out:
#         ticket_id                          ticket_trace/contact
# 0               0                                          0, 1
# 1               1  1-2458-98519-115061-140081-165605-476346, 12
# 2               2                     2-159312-322639-348955, 4
# 3               3                                          3, 0
# 4               4                                          4, 2
# ...           ...                                           ...
# 499995     499995                                     499995, 2
# 499996     499996                                     499996, 4
# 499997     499997                                     499997, 2
# 499998     499998                              121111-499998, 5
# 499999     499999                                     499999, 0
#
# [500000 rows x 2 columns]
